# %%
##selecao de atributos
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.svm import SVC
from sklearn.ensemble import ExtraTreesClassifier

# %%
cetam=pd.read_excel('Aval_cetam_f_v8.xlsx')
cetam.head()
# Out:
#   Qual sua idade? Qual seu genero?   Qual sua renda familiar?  \
# 0           19-22         Feminino  Entre R$ 1.000 e R$ 2.000
# 1     Acima de 30        Masculino          Menos de R$ 1.000
# 2           23-26         Feminino          Menos de R$ 1.000
# 3           19-22        Masculino  Entre R$ 1.000 e R$ 2.000
# 4     Acima de 30         Feminino          Menos de R$ 1.000
#
#   Qual regiao da cidade voce mora? Qual a sua escola?  \
# 0                            Norte           Saavedra
# 1                            Norte           Saavedra
# 2                            Norte           Saavedra
# 3                            Norte           Saavedra
# 4                            Leste           Saavedra
#
#   Qual o percentual da sua formacao no CETAM ja foi concluida?  \
# 0                           Acima de 75% (Finalista)
# 1                           Acima de 75% (Finalista)
# 2                           Acima de 75% (Finalista)
# ...

# %%
#formato da matriz
previsores=cetam.iloc[:,0:13].values
classe=cetam.iloc[:,13].values

# %%
#transformar os atributos categoricos em atributos numericos, passando o indice de cada coluna categorica
#criacao de um objeto para cada atributo categorico
labelencoder=LabelEncoder()
previsores[:,0]=labelencoder.fit_transform(previsores[:,0])
previsores[:,1]=labelencoder.fit_transform(previsores[:,1])
previsores[:,2]=labelencoder.fit_transform(previsores[:,2])
previsores[:,3]=labelencoder.fit_transform(previsores[:,3])
previsores[:,4]=labelencoder.fit_transform(previsores[:,4])
previsores[:,5]=labelencoder.fit_transform(previsores[:,5])
previsores[:,6]=labelencoder.fit_transform(previsores[:,6])
previsores[:,7]=labelencoder.fit_transform(previsores[:,7])
previsores[:,8]=labelencoder.fit_transform(previsores[:,8])
previsores[:,9]=labelencoder.fit_transform(previsores[:,9])
previsores[:,10]=labelencoder.fit_transform(previsores[:,10])
previsores[:,11]=labelencoder.fit_transform(previsores[:,11])
previsores[:,12]=labelencoder.fit_transform(previsores[:,12])

# %%
#divisao da base de dados entre treinamento e teste (30% testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste= train_test_split(previsores, 
                                                                 classe, 
                                                                 test_size=0.3,
                                                                 random_state=1)

# %%
#criacao do modelo, treinamento, obtencao das previsoes e da taxa de acerto
svm=SVC()
svm.fit(X_treinamento, y_treinamento)
# Out:
# SVC()

# %%
#previsoes
previsoes=svm.predict(X_teste)
previsoes
# Out:
# array(['NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ',
#        'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ',
#        'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ',
#        'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ',
#        'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ',
#        'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO ',
#        'NAO ', 'NAO ', 'NAO ', 'NAO ', 'NAO '], dtype=object)

# %%
taxa_acerto=accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.8490566037735849

# %%
#utlizacao do algoritmo ExtraTreesClassifier para extrair as caractieristicas mais importantes
forest= ExtraTreesClassifier()
forest.fit(X_treinamento, y_treinamento)
importancias=forest.feature_importances_
importancias
# Out:
# array([0.11657262, 0.02634634, 0.08537697, 0.16576401, 0.0366752 ,
#        0.        , 0.02457417, 0.02648718, 0.1356772 , 0.05452451,
#        0.06851654, 0.05302786, 0.2064574 ])

# %%
for i in importancias:
    print(i)
# Out:
# 0.11657261860490309
# 0.026346341720117385
# 0.08537696610592316
# 0.1657640074266976
# 0.036675202733815304
# 0.0
# 0.024574166220074
# 0.026487184981307952
# 0.13567720207053863
# 0.05452451034490256
# 0.0685165381455996
# 0.053027862448505145
# 0.20645739919761555

# %%
VALOR	ATRIBUTO
#0.11040428149692752	Qual sua idade?                                                      0
0.026579921826771553	Qual seu genero?                                                     0
0.09478739710541238	Qual sua renda familiar?                                             0
#0.16490198584964472	Qual regiao da cidade voce mora?                                     0
0.03571929103901822	Qual a sua escola?                                                   0
0.0	Qual o percentual da sua formacao no CETAM ja foi concluida?         0
0.02899321879682359	Qual tipo do seu curso?                                              0
0.028087376068212103	Qual o eixo tecnologico?                                             0
#0.13957702739893801	Qual o seu curso?                                                    0
0.05050238815355612	Qual sua formacao regular?                                           0
0.06725865760208737	Qual sua disponibilidade de horario para atividade remunerada?       0
0.047748902352610895	Qual sua carga horaria disponivel?                                   0
#0.20543955230999741	Possui experiencia na area de formacao do curso?                     0
# Out:
#   File "<ipython-input-46-feb840d4f3b6>", line 1
#     VALOR	ATRIBUTO
#          	^
# SyntaxError: invalid syntax

# %%
X_treinamento2=X_treinamento[:,[0,1]]
X_teste2=X_teste[:,[0,1]]

# %%
svm2=SVC()
svm2.fit(X_treinamento2,y_treinamento)
previsoes2=svm2.predict(X_teste2)
taxa_acerto2=accuracy_score(y_teste,previsoes2)
taxa_acerto2
# Out:
# 0.8490566037735849
